# %% [markdown]
# <a href="https://colab.research.google.com/github/masolopa/MINERIADEDATOS/blob/main/EV1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

#El contexto del data set es sobre las estimaciones de taza de pobreza multidimensional por comuna en Chile del año 2015
#Integrantes: Alejandra Guzman - Macarena Lobos Sección 002D
#https://github.com/masolopa/MINERIADEDATOS

# %%
#Se importa el data set del año 2015
df = pd.read_excel("/content/planilla_estimaciones_pobreza_2015.xlsx")

# %%
#Se observa el data frame en bruto
df
# Out:
#     Estimaciones de Tasa de Pobreza Multidimensional por Comuna, considerando Entorno y Redes y Aplicación de Metodologías de: Estimación directa, Estimación para Áreas Pequeñas (SAE) e Imputación de Medias por Conglomerados (IMC), 2015  \
# 0                                                  NaN
# 1                                               Código
# 2                                                 1101
# 3                                                 1107
# 4                                                 1401
# ..                                                 ...
# 342                                              14204
# 343                                              15101
# 344                                              15102
# 345                                              15201
# 346                                              15202
#
#                     Unnamed: 1     Unnamed: 2  \
# 0                          NaN            NaN
# 1                       Región  Nombre comuna
# 2               I de Tarapacá         Iquique
# 3               I de Tarapacá   Alto Hospicio
# 4               I de Tarapacá    Pozo Almonte
# ..                         ...            ...
# 342            XIV de los Ríos      Rio Bueno
# 343  XV de Arica y Parinacota           Arica
# 344  XV de Arica y Parinacota       Camarones
# 345  XV de Arica y Parinacota           Putre
# 346  XV de Arica y Parinacota   General Lagos
#
#                                             Unnamed: 3  \
# 0                                                  NaN
# 1    Número de personas en situación de pobreza por...
# 2                                                 9491
# 3                                                 9768
# 4                                                 1515
# ..                                                 ...
# 342                                               5113
# 343                                              14573
# 344                                           217.5172
# 345                                                240
# 346                                           267.9631
#
#                                             Unnamed: 4       Unnamed: 5  \
# 0                                                  NaN              NaN
# 1    Porcentaje de personas en situación de pobreza...  Límite inferior
# 2                                             0.053294         0.034605
# 3                                             0.085072         0.064137
# 4                                             0.103265         0.072762
# ..                                                 ...              ...
# 342                                           0.171232         0.107617
# 343                                           0.088609         0.068152
# 344                                           0.146674          0.07265
# 345                                           0.311284           0.2193
# 346                                           0.277395              NaN
#
#           Unnamed: 6                 Unnamed: 7
# 0                NaN                        NaN
# 1    Límite superior  Metodología de Estimación
# 2           0.081227         Estimación Directa
# 3           0.112023         Estimación Directa
# 4           0.144562         Estimación Directa
# ..               ...                        ...
# 342         0.261436         Estimación Directa
# 343         0.114452         Estimación Directa
# 344         0.241199                        SAE
# 345         0.421043         Estimación Directa
# 346              NaN                        IMC
#
# [347 rows x 8 columns]

# %%
#Se eliminan las primeras dos filas del data frame seleccionando el número de posición de cada fila a la vez
df = df.drop(index= [0, 1])

# %%
#Se observa el data frame con las dos filas de posición 0 y 1 eliminadas
df
# Out:
#     Estimaciones de Tasa de Pobreza Multidimensional por Comuna, considerando Entorno y Redes y Aplicación de Metodologías de: Estimación directa, Estimación para Áreas Pequeñas (SAE) e Imputación de Medias por Conglomerados (IMC), 2015  \
# 2                                                 1101
# 3                                                 1107
# 4                                                 1401
# 5                                                 1402
# 6                                                 1403
# ..                                                 ...
# 342                                              14204
# 343                                              15101
# 344                                              15102
# 345                                              15201
# 346                                              15202
#
#                     Unnamed: 1     Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 2               I de Tarapacá         Iquique       9491   0.053294
# 3               I de Tarapacá   Alto Hospicio       9768   0.085072
# 4               I de Tarapacá    Pozo Almonte       1515   0.103265
# 5               I de Tarapacá          Camiña   300.2006   0.348665
# 6               I de Tarapacá        Colchane   328.2058   0.239566
# ..                         ...            ...        ...        ...
# 342            XIV de los Ríos      Rio Bueno       5113   0.171232
# 343  XV de Arica y Parinacota           Arica      14573   0.088609
# 344  XV de Arica y Parinacota       Camarones   217.5172   0.146674
# 345  XV de Arica y Parinacota           Putre        240   0.311284
# 346  XV de Arica y Parinacota   General Lagos   267.9631   0.277395
#
#     Unnamed: 5 Unnamed: 6          Unnamed: 7
# 2     0.034605   0.081227  Estimación Directa
# 3     0.064137   0.112023  Estimación Directa
# 4     0.072762   0.144562  Estimación Directa
# 5     0.276406   0.453704                 SAE
# 6          NaN        NaN                 IMC
# ..         ...        ...                 ...
# 342   0.107617   0.261436  Estimación Directa
# 343   0.068152   0.114452  Estimación Directa
# 344    0.07265   0.241199                 SAE
# 345     0.2193   0.421043  Estimación Directa
# 346        NaN        NaN                 IMC
#
# [345 rows x 8 columns]

# %%
#Se consultan los nombres de las columnas del data frame
print("Nombres de columnas actuales:")
print(df.columns.tolist())
# Out:
# Nombres de columnas actuales:
# ['Estimaciones de Tasa de Pobreza Multidimensional por Comuna, considerando Entorno y Redes y Aplicación de Metodologías de: Estimación directa, Estimación para Áreas Pequeñas (SAE) e Imputación de Medias por Conglomerados (IMC), 2015', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7']

# %%
#Se renombran las columnas
df.columns = ['Código comuna', 'Región','Nombre comuna', 'Número de personas en situación de pobreza por ingresos','Porcentaje de personas en situación de pobreza por ingresos', 'Límite inferior','Límite superior', 'Metodología de Estimación']
display(df.head())
# Out:
#   Código comuna          Región  Nombre comuna  \
# 2          1101  I de Tarapacá         Iquique
# 3          1107  I de Tarapacá   Alto Hospicio
# 4          1401  I de Tarapacá    Pozo Almonte
# 5          1402  I de Tarapacá          Camiña
# 6          1403  I de Tarapacá        Colchane
#
#   Número de personas en situación de pobreza por ingresos  \
# 2                                               9491
# 3                                               9768
# 4                                               1515
# 5                                           300.2006
# 6                                           328.2058
#
#   Porcentaje de personas en situación de pobreza por ingresos Límite inferior  \
# 2                                           0.053294                 0.034605
# 3                                           0.085072                 0.064137
# 4                                           0.103265                 0.072762
# 5                                           0.348665                 0.276406
# 6                                           0.239566                      NaN
#
#   Límite superior Metodología de Estimación
# 2        0.081227        Estimación Directa
# 3        0.112023        Estimación Directa
# 4        0.144562        Estimación Directa
# 5        0.453704                       SAE
# 6             NaN                       IMC

# %%
#df.to_csv("modificado.csv") Se hace una conversión del data frame a versión csv, ya que la base de origen es tipo excel

# %%
#Se muestran las primeras 5 filas
df.head()
# Out:
#   Código comuna          Región  Nombre comuna  \
# 2          1101  I de Tarapacá         Iquique
# 3          1107  I de Tarapacá   Alto Hospicio
# 4          1401  I de Tarapacá    Pozo Almonte
# 5          1402  I de Tarapacá          Camiña
# 6          1403  I de Tarapacá        Colchane
#
#   Número de personas en situación de pobreza por ingresos  \
# 2                                               9491
# 3                                               9768
# 4                                               1515
# 5                                           300.2006
# 6                                           328.2058
#
#   Porcentaje de personas en situación de pobreza por ingresos Límite inferior  \
# 2                                           0.053294                 0.034605
# 3                                           0.085072                 0.064137
# 4                                           0.103265                 0.072762
# 5                                           0.348665                 0.276406
# 6                                           0.239566                      NaN
#
#   Límite superior Metodología de Estimación
# 2        0.081227        Estimación Directa
# 3        0.112023        Estimación Directa
# 4        0.144562        Estimación Directa
# 5        0.453704                       SAE
# 6             NaN                       IMC

# %%
#Se muestran las últimas 5 filas del data frame
df.tail()
# Out:
#     Código comuna                     Región  Nombre comuna  \
# 342         14204            XIV de los Ríos      Rio Bueno
# 343         15101  XV de Arica y Parinacota           Arica
# 344         15102  XV de Arica y Parinacota       Camarones
# 345         15201  XV de Arica y Parinacota           Putre
# 346         15202  XV de Arica y Parinacota   General Lagos
#
#     Número de personas en situación de pobreza por ingresos  \
# 342                                               5113
# 343                                              14573
# 344                                           217.5172
# 345                                                240
# 346                                           267.9631
#
#     Porcentaje de personas en situación de pobreza por ingresos  \
# 342                                           0.171232
# 343                                           0.088609
# 344                                           0.146674
# 345                                           0.311284
# 346                                           0.277395
#
#     Límite inferior Límite superior Metodología de Estimación
# 342        0.107617        0.261436        Estimación Directa
# 343        0.068152        0.114452        Estimación Directa
# 344         0.07265        0.241199                       SAE
# 345          0.2193        0.421043        Estimación Directa
# 346             NaN             NaN                       IMC

# %%
#Se listan las columnas del data frame
df.columns
# Out:
# Index(['Código comuna', 'Región', 'Nombre comuna',
#        'Número de personas en situación de pobreza por ingresos',
#        'Porcentaje de personas en situación de pobreza por ingresos',
#        'Límite inferior', 'Límite superior', 'Metodología de Estimación'],
#       dtype='object')

# %%
#Se revisan los valores nulos de cada columna del data frame
df.isna().sum()
# Out:
# Código comuna                                                   0
# Región                                                          0
# Nombre comuna                                                   0
# Número de personas en situación de pobreza por ingresos         0
# Porcentaje de personas en situación de pobreza por ingresos     0
# Límite inferior                                                21
# Límite superior                                                21
# Metodología de Estimación                                       0
# dtype: int64

# %%
#Se importa el data set del año 2024
df2 = pd.read_excel("/content/sae_multidimensional_2024.xlsx")

# %%
df2
# Out:
#     Estimaciones de Índice de Pobreza Multidimensional por comuna. Aplicación de Metodologías de Estimación para Áreas Pequeñas (SAE) 2024  \
# 0                                                  NaN
# 1                                               Código
# 2                                                 1101
# 3                                                 1107
# 4                                                 1401
# ..                                                 ...
# 348  La metodología de áreas pequeñas busca realiza...
# 349  Las estimaciones presentadas se basan en la nu...
# 350  (*) Proyecciones de población comunal en vivie...
# 351  (**) Este número se obtiene de multiplicar las...
# 352  (***) Las estimaciones para área pequeña asign...
#
#     Unnamed: 1     Unnamed: 2  \
# 0          NaN            NaN
# 1       Región  Nombre comuna
# 2     Tarapacá        Iquique
# 3     Tarapacá  Alto Hospicio
# 4     Tarapacá   Pozo Almonte
# ..         ...            ...
# 348        NaN            NaN
# 349        NaN            NaN
# 350        NaN            NaN
# 351        NaN            NaN
# 352        NaN            NaN
#
#                                             Unnamed: 3  \
# 0                                                  NaN
# 1    Número de personas según proyecciones de pobla...
# 2                                               232455
# 3                                               144554
# 4                                                18811
# ..                                                 ...
# 348                                                NaN
# 349                                                NaN
# 350                                                NaN
# 351                                                NaN
# 352                                                NaN
#
#                                             Unnamed: 4  \
# 0                                                  NaN
# 1    Número de personas en situación de pobreza mul...
# 2                                         43108.781225
# 3                                         40866.517698
# 4                                          3646.420183
# ..                                                 ...
# 348                                                NaN
# 349                                                NaN
# 350                                                NaN
# 351                                                NaN
# 352                                                NaN
#
#                                             Unnamed: 5       Unnamed: 6  \
# 0                                                  NaN              NaN
# 1    Porcentaje de personas en situacion de pobreza...  Límite inferior
# 2                                              0.18545         0.163506
# 3                                             0.282708         0.255357
# 4                                             0.193845         0.142099
# ..                                                 ...              ...
# 348                                                NaN              NaN
# 349                                                NaN              NaN
# 350                                                NaN              NaN
# 351                                                NaN              NaN
# 352                                                NaN              NaN
#
#           Unnamed: 7                                  Unnamed: 8  \
# 0                NaN                                         NaN
# 1    Límite superior  Presencia de la comuna en la muestra Casen
# 2           0.207394                                          Sí
# 3           0.310058                                          Sí
# 4           0.245592                                          Sí
# ..               ...                                         ...
# 348              NaN                                         NaN
# 349              NaN                                         NaN
# 350              NaN                                         NaN
# 351              NaN                                         NaN
# 352              NaN                                         NaN
#
#                             Unnamed: 9
# 0                                  NaN
# 1         Tipo de estimación SAE (***)
# 2    Directa y Sintética (Fay-Herriot)
# 3    Directa y Sintética (Fay-Herriot)
# 4    Directa y Sintética (Fay-Herriot)
# ..                                 ...
# 348                                NaN
# 349                                NaN
# 350                                NaN
# 351                                NaN
# 352                                NaN
#
# [353 rows x 10 columns]

# %%
#Se eliminan las primeras dos filas del data frame 2 seleccionando el número de posición de cada fila a la vez
df2 = df2.drop(index= [0, 1])

# %%
#Se renombran las columnas
df2.columns = ['Código comuna', 'Región','Nombre comuna', 'Número de personas según proyecciones de población (*)','Número de personas en situación de pobreza multidimensional (**)', 'Porcentaje de personas en situacion de pobreza multidimensional 2024','Límite inferior', 'Límite superior', 'Presencia de la comuna en la muestra Casen', 'Tipo de estimación SAE (***)']
display(df.head())
# Out:
#   Código comuna          Región  Nombre comuna  \
# 2          1101  I de Tarapacá         Iquique
# 3          1107  I de Tarapacá   Alto Hospicio
# 4          1401  I de Tarapacá    Pozo Almonte
# 5          1402  I de Tarapacá          Camiña
# 6          1403  I de Tarapacá        Colchane
#
#   Número de personas en situación de pobreza por ingresos  \
# 2                                               9491
# 3                                               9768
# 4                                               1515
# 5                                           300.2006
# 6                                           328.2058
#
#   Porcentaje de personas en situación de pobreza por ingresos Límite inferior  \
# 2                                           0.053294                 0.034605
# 3                                           0.085072                 0.064137
# 4                                           0.103265                 0.072762
# 5                                           0.348665                 0.276406
# 6                                           0.239566                      NaN
#
#   Límite superior Metodología de Estimación
# 2        0.081227        Estimación Directa
# 3        0.112023        Estimación Directa
# 4        0.144562        Estimación Directa
# 5        0.453704                       SAE
# 6             NaN                       IMC

# %%
#Se muestran las últimas 5 filas del data frame 2
df2.tail()
# Out:
#                                          Código comuna Región Nombre comuna  \
# 348  La metodología de áreas pequeñas busca realiza...    NaN           NaN
# 349  Las estimaciones presentadas se basan en la nu...    NaN           NaN
# 350  (*) Proyecciones de población comunal en vivie...    NaN           NaN
# 351  (**) Este número se obtiene de multiplicar las...    NaN           NaN
# 352  (***) Las estimaciones para área pequeña asign...    NaN           NaN
#
#     Número de personas según proyecciones de población (*)  \
# 348                                                NaN
# 349                                                NaN
# 350                                                NaN
# 351                                                NaN
# 352                                                NaN
#
#     Número de personas en situación de pobreza multidimensional (**)  \
# 348                                                NaN
# 349                                                NaN
# 350                                                NaN
# 351                                                NaN
# 352                                                NaN
#
#     Porcentaje de personas en situacion de pobreza multidimensional 2024  \
# 348                                                NaN
# 349                                                NaN
# 350                                                NaN
# 351                                                NaN
# 352                                                NaN
#
#     Límite inferior Límite superior  \
# 348             NaN             NaN
# 349             NaN             NaN
# 350             NaN             NaN
# 351             NaN             NaN
# 352             NaN             NaN
#
#     Presencia de la comuna en la muestra Casen Tipo de estimación SAE (***)
# 348                                        NaN                          NaN
# 349                                        NaN                          NaN
# 350                                        NaN                          NaN
# 351                                        NaN                          NaN
# 352                                        NaN                          NaN

# %%
df.info() #Muestra en detalle cuantas columnas hay, sus nombres, también muestra que hay 345 filas de datos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345 entries, 2 to 346
# Data columns (total 8 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Código comuna                                                345 non-null    object
#  1   Región                                                       345 non-null    object
#  2   Nombre comuna                                                345 non-null    object
#  3   Número de personas en situación de pobreza por ingresos      345 non-null    object
#  4   Porcentaje de personas en situación de pobreza por ingresos  345 non-null    object
#  5   Límite inferior                                              324 non-null    object
#  6   Límite superior                                              324 non-null    object
#  7   Metodología de Estimación                                    345 non-null    object
# dtypes: object(8)
# memory usage: 21.7+ KB

# %%
#df2.to_csv("modificado2.csv")

# %%
df2.info()#Muestra en detalle cuantas columnas hay, sus nombres, también muestra que hay 350 filas de datos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 2 to 352
# Data columns (total 10 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Código comuna                                                         350 non-null    object
#  1   Región                                                                345 non-null    object
#  2   Nombre comuna                                                         345 non-null    object
#  3   Número de personas según proyecciones de población (*)                345 non-null    object
#  4   Número de personas en situación de pobreza multidimensional (**)      345 non-null    object
#  5   Porcentaje de personas en situacion de pobreza multidimensional 2024  345 non-null    object
#  6   Límite inferior                                                       345 non-null    object
#  7   Límite superior                                                       345 non-null    object
#  8   Presencia de la comuna en la muestra Casen                            345 non-null    object
#  9   Tipo de estimación SAE (***)                                          345 non-null    object
# dtypes: object(10)
# memory usage: 27.6+ KB

# %%
df.shape #Muestra filas y luego columnas totales
# Out:
# (345, 8)

# %%
df2.shape #Muestra filas y luego columnas totales
# Out:
# (351, 10)

# %%
df.dtypes #Muestra el tipo de dato de cada columna
# Out:
# Código comuna                                                  object
# Región                                                         object
# Nombre comuna                                                  object
# Número de personas en situación de pobreza por ingresos        object
# Porcentaje de personas en situación de pobreza por ingresos    object
# Límite inferior                                                object
# Límite superior                                                object
# Metodología de Estimación                                      object
# dtype: object

# %%
df2.dtypes #Muestra el tipo de dato de cada columna
# Out:
# Código comuna                                                           object
# Región                                                                  object
# Nombre comuna                                                           object
# Número de personas según proyecciones de población (*)                  object
# Número de personas en situación de pobreza multidimensional (**)        object
# Porcentaje de personas en situacion de pobreza multidimensional 2024    object
# Límite inferior                                                         object
# Límite superior                                                         object
# Presencia de la comuna en la muestra Casen                              object
# Tipo de estimación SAE (***)                                            object
# dtype: object

# %%
df.describe() #Muestra estadísticas descriptivas de las columnas numéricas
# Out:
#         Código comuna           Región  Nombre comuna  \
# count             345              345            345
# unique            345               15            345
# top             15202  VIII del Biobío  General Lagos
# freq                1               54              1
#
#         Número de personas en situación de pobreza por ingresos  \
# count                                                 345
# unique                                                344
# top                                                  4632
# freq                                                    2
#
#         Porcentaje de personas en situación de pobreza por ingresos  \
# count                                          345.000000
# unique                                         343.000000
# top                                              0.171126
# freq                                             2.000000
#
#         Límite inferior  Límite superior Metodología de Estimación
# count          324.0000       324.000000                       345
# unique         324.0000       324.000000                         3
# top              0.2193         0.421043                       SAE
# freq             1.0000         1.000000                       185

# %%
df2.describe() #Muestra estadísticas descriptivas de las columnas numéricas
# Out:
#                                             Código comuna         Región  \
# count                                                 350            345
# unique                                                350             16
# top     (***) Las estimaciones para área pequeña asign...  Metropolitana
# freq                                                    1             52
#
#        Nombre comuna  Número de personas según proyecciones de población (*)  \
# count            345                                                345
# unique           345                                                342
# top      San Nicolás                                              19779
# freq               1                                                  2
#
#         Número de personas en situación de pobreza multidimensional (**)  \
# count                                          345.000000
# unique                                         345.000000
# top                                           1855.039212
# freq                                             1.000000
#
#         Porcentaje de personas en situacion de pobreza multidimensional 2024  \
# count                                          345.000000
# unique                                         345.000000
# top                                              0.148119
# freq                                             1.000000
#
#         Límite inferior  Límite superior  \
# count               345       345.000000
# unique              340       345.000000
# top                   0         0.189405
# freq                  6         1.000000
#
#        Presencia de la comuna en la muestra Casen  \
# count                                         345
# unique                                          2
# top                                            Sí
# freq                                          335
#
#              Tipo de estimación SAE (***)
# count                                 345
# unique                                  2
# top     Directa y Sintética (Fay-Herriot)
# freq                                  294

# %%
df.isna().sum() #Se cuentan el total de los valores faltantes por cada columna, aquí se visualiza que en la columna limite inferior y en la columna limite superior del data frame 2015 hay 21 nulos
# Out:
# Código comuna                                                   0
# Región                                                          0
# Nombre comuna                                                   0
# Número de personas en situación de pobreza por ingresos         0
# Porcentaje de personas en situación de pobreza por ingresos     0
# Límite inferior                                                21
# Límite superior                                                21
# Metodología de Estimación                                       0
# dtype: int64

# %%
df2.isna().sum()  #Se cuentan el total de los valores faltantes por cada columna, aquí se visualiza que en las 10 columnas del data frame 2024 hay nulos
# Out:
# Código comuna                                                           1
# Región                                                                  6
# Nombre comuna                                                           6
# Número de personas según proyecciones de población (*)                  6
# Número de personas en situación de pobreza multidimensional (**)        6
# Porcentaje de personas en situacion de pobreza multidimensional 2024    6
# Límite inferior                                                         6
# Límite superior                                                         6
# Presencia de la comuna en la muestra Casen                              6
# Tipo de estimación SAE (***)                                            6
# dtype: int64

# %%
df.describe() #Estadistica descriptiva sobre variables numericas, se muestra que en la comuna General lagos de la región del Biobio se encuentra mayor cantidad de muestras al año 2015
# Out:
#         Código comuna           Región  Nombre comuna  \
# count             345              345            345
# unique            345               15            345
# top             15202  VIII del Biobío  General Lagos
# freq                1               54              1
#
#         Número de personas en situación de pobreza por ingresos  \
# count                                                 345
# unique                                                344
# top                                                  4632
# freq                                                    2
#
#         Porcentaje de personas en situación de pobreza por ingresos  \
# count                                          345.000000
# unique                                         343.000000
# top                                              0.171126
# freq                                             2.000000
#
#         Límite inferior  Límite superior Metodología de Estimación
# count          324.0000       324.000000                       345
# unique         324.0000       324.000000                         3
# top              0.2193         0.421043                       SAE
# freq             1.0000         1.000000                       185

# %%
df2.describe() #Estadistica descriptiva sobre variables numericas, se puede interpretar que en la comuna de San Nicolás de la Región Metropolitana es en donde hubieron más muestras al año 2024
# Out:
#                                             Código comuna         Región  \
# count                                                 350            345
# unique                                                350             16
# top     (***) Las estimaciones para área pequeña asign...  Metropolitana
# freq                                                    1             52
#
#        Nombre comuna  Número de personas según proyecciones de población (*)  \
# count            345                                                345
# unique           345                                                342
# top      San Nicolás                                              19779
# freq               1                                                  2
#
#         Número de personas en situación de pobreza multidimensional (**)  \
# count                                          345.000000
# unique                                         345.000000
# top                                           1855.039212
# freq                                             1.000000
#
#         Porcentaje de personas en situacion de pobreza multidimensional 2024  \
# count                                          345.000000
# unique                                         345.000000
# top                                              0.148119
# freq                                             1.000000
#
#         Límite inferior  Límite superior  \
# count               345       345.000000
# unique              340       345.000000
# top                   0         0.189405
# freq                  6         1.000000
#
#        Presencia de la comuna en la muestra Casen  \
# count                                         345
# unique                                          2
# top                                            Sí
# freq                                          335
#
#              Tipo de estimación SAE (***)
# count                                 345
# unique                                  2
# top     Directa y Sintética (Fay-Herriot)
# freq                                  294

# %%
df.drop
# Out:
# <bound method DataFrame.drop of     Código comuna                     Región  Nombre comuna  \
# 2            1101             I de Tarapacá         Iquique
# 3            1107             I de Tarapacá   Alto Hospicio
# 4            1401             I de Tarapacá    Pozo Almonte
# 5            1402             I de Tarapacá          Camiña
# 6            1403             I de Tarapacá        Colchane
# ..            ...                        ...            ...
# 342         14204            XIV de los Ríos      Rio Bueno
# 343         15101  XV de Arica y Parinacota           Arica
# 344         15102  XV de Arica y Parinacota       Camarones
# 345         15201  XV de Arica y Parinacota           Putre
# 346         15202  XV de Arica y Parinacota   General Lagos
#
#     Número de personas en situación de pobreza por ingresos  \
# 2                                                 9491
# 3                                                 9768
# 4                                                 1515
# 5                                             300.2006
# 6                                             328.2058
# ..                                                 ...
# 342                                               5113
# 343                                              14573
# 344                                           217.5172
# 345                                                240
# 346                                           267.9631
#
#     Porcentaje de personas en situación de pobreza por ingresos  \
# 2                                             0.053294
# 3                                             0.085072
# 4                                             0.103265
# 5                                             0.348665
# 6                                             0.239566
# ..                                                 ...
# 342                                           0.171232
# 343                                           0.088609
# 344                                           0.146674
# 345                                           0.311284
# 346                                           0.277395
#
#     Límite inferior Límite superior Metodología de Estimación
# 2          0.034605        0.081227        Estimación Directa
# 3          0.064137        0.112023        Estimación Directa
# 4          0.072762        0.144562        Estimación Directa
# 5          0.276406        0.453704                       SAE
# 6               NaN             NaN                       IMC
# ..              ...             ...                       ...
# 342        0.107617        0.261436        Estimación Directa
# 343        0.068152        0.114452        Estimación Directa
# 344         0.07265        0.241199                       SAE
# 345          0.2193        0.421043        Estimación Directa
# 346             NaN             NaN                       IMC
#
# [345 rows x 8 columns]>

# %%
df2.drop
# Out:
# <bound method DataFrame.drop of                                          Código comuna    Región  \
# 2                                                 1101  Tarapacá
# 3                                                 1107  Tarapacá
# 4                                                 1401  Tarapacá
# 5                                                 1402  Tarapacá
# 6                                                 1403  Tarapacá
# ..                                                 ...       ...
# 348  La metodología de áreas pequeñas busca realiza...       NaN
# 349  Las estimaciones presentadas se basan en la nu...       NaN
# 350  (*) Proyecciones de población comunal en vivie...       NaN
# 351  (**) Este número se obtiene de multiplicar las...       NaN
# 352  (***) Las estimaciones para área pequeña asign...       NaN
#
#      Nombre comuna Número de personas según proyecciones de población (*)  \
# 2          Iquique                                             232455
# 3    Alto Hospicio                                             144554
# 4     Pozo Almonte                                              18811
# 5           Camiña                                               1376
# 6         Colchane                                               1553
# ..             ...                                                ...
# 348            NaN                                                NaN
# 349            NaN                                                NaN
# 350            NaN                                                NaN
# 351            NaN                                                NaN
# 352            NaN                                                NaN
#
#     Número de personas en situación de pobreza multidimensional (**)  \
# 2                                         43108.781225
# 3                                         40866.517698
# 4                                          3646.420183
# 5                                           427.722222
# 6                                           504.646121
# ..                                                 ...
# 348                                                NaN
# 349                                                NaN
# 350                                                NaN
# 351                                                NaN
# 352                                                NaN
#
#     Porcentaje de personas en situacion de pobreza multidimensional 2024  \
# 2                                              0.18545
# 3                                             0.282708
# 4                                             0.193845
# 5                                             0.310845
# 6                                             0.324949
# ..                                                 ...
# 348                                                NaN
# 349                                                NaN
# 350                                                NaN
# 351                                                NaN
# 352                                                NaN
#
#     Límite inferior Límite superior  \
# 2          0.163506        0.207394
# 3          0.255357        0.310058
# 4          0.142099        0.245592
# 5          0.222186        0.399503
# 6          0.242101        0.407797
# ..              ...             ...
# 348             NaN             NaN
# 349             NaN             NaN
# 350             NaN             NaN
# 351             NaN             NaN
# 352             NaN             NaN
#
#     Presencia de la comuna en la muestra Casen  \
# 2                                           Sí
# 3                                           Sí
# 4                                           Sí
# 5                                           Sí
# 6                                           Sí
# ..                                         ...
# 348                                        NaN
# 349                                        NaN
# 350                                        NaN
# 351                                        NaN
# 352                                        NaN
#
#           Tipo de estimación SAE (***)
# 2    Directa y Sintética (Fay-Herriot)
# 3    Directa y Sintética (Fay-Herriot)
# 4    Directa y Sintética (Fay-Herriot)
# 5                            Sintética
# 6                            Sintética
# ..                                 ...
# 348                                NaN
# 349                                NaN
# 350                                NaN
# 351                                NaN
# 352                                NaN
#
# [351 rows x 10 columns]>

# %%
#Agrupación de las columnas por tipos de datos

tipos= df.columns.to_series().groupby(df.dtypes).groups

#Conociendo la lista de columnas categoricas

ctext =tipos[np.dtype('object')]
len(ctext) #Cantidad de columnas con datos categóricos
# Out:
# 8

# %%
#Conociendo la lista de columnas numéricas

columnas = df.columns
cnum = list(set(columnas) - set(ctext))
len(cnum)
# Out:
# 0

# %%
#Conociendo la lista de columnas numéricas

columnas = df2.columns
cnum = list(set(columnas) - set(ctext))
len(cnum)
# Out:
# 5

# %%
#Se comprueban los nulos del df
df.isnull().any().any()
# Out:
# np.True_

# %%
#Se comprueban los nulos del df2
df2.isnull().any().any()
# Out:
# np.True_

# %%
ascn_order= np.sort(df["Código comuna"].unique())  #Aquí ordena los códigos de las comunas en orden ascendente
print(ascn_order)
# Out:
# [1101 1107 1401 1402 1403 1404 1405 2101 2102 2103 2104 2201 2202 2203
#  2301 2302 3101 3102 3103 3201 3202 3301 3302 3303 3304 4101 4102 4103
#  4104 4105 4106 4201 4202 4203 4204 4301 4302 4303 4304 4305 5101 5102
#  5103 5104 5105 5107 5109 5201 5301 5302 5303 5304 5401 5402 5403 5404
#  5405 5501 5502 5503 5504 5506 5601 5602 5603 5604 5605 5606 5701 5702
#  5703 5704 5705 5706 5801 5802 5803 5804 6101 6102 6103 6104 6105 6106
#  6107 6108 6109 6110 6111 6112 6113 6114 6115 6116 6117 6201 6202 6203
#  6204 6205 6206 6301 6302 6303 6304 6305 6306 6307 6308 6309 6310 7101
#  7102 7103 7104 7105 7106 7107 7108 7109 7110 7201 7202 7203 7301 7302
#  7303 7304 7305 7306 7307 7308 7309 7401 7402 7403 7404 7405 7406 7407
#  7408 8101 8102 8103 8104 8105 8106 8107 8108 8109 8110 8111 8112 8201
#  8202 8203 8204 8205 8206 8207 8301 8302 8303 8304 8305 8306 8307 8308
#  8309 8310 8311 8312 8313 8314 8401 8402 8403 8404 8405 8406 8407 8408
#  8409 8410 8411 8412 8413 8414 8415 8416 8417 8418 8419 8420 8421 9101
#  9102 9103 9104 9105 9106 9107 9108 9109 9110 9111 9112 9113 9114 9115
#  9116 9117 9118 9119 9120 9121 9201 9202 9203 9204 9205 9206 9207 9208
#  9209 9210 9211 10101 10102 10103 10104 10105 10106 10107 10108 10109
#  10201 10202 10203 10204 10205 10206 10207 10208 10209 10210 10301 10302
#  10303 10304 10305 10306 10307 10401 10402 10403 10404 11101 11102 11201
#  11202 11203 11301 11302 11303 11401 11402 12101 12102 12103 12104 12201
#  12301 12302 12303 12401 12402 13101 13102 13103 13104 13105 13106 13107
#  13108 13109 13110 13111 13112 13113 13114 13115 13116 13117 13118 13119
#  13120 13121 13122 13123 13124 13125 13126 13127 13128 13129 13130 13131
#  13132 13201 13202 13203 13301 13302 13303 13401 13402 13403 13404 13501
#  13502 13503 13504 13505 13601 13602 13603 13604 13605 14101 14102 14103
#  14104 14105 14106 14107 14108 14201 14202 14203 14204 15101 15102 15201
#  15202]

# %%
df['Región'].value_counts()#Aquí me muestra las cantidades de personas por región que han sido consideradas para la evaluación
# Out:
# Región
# VIII del Biobío                                  54
# XIII Metropolitana de Santiago                   52
# V de Valparaíso                                  38
# VI del Libertador General Bernardo O'Higgins     33
# IX de la Araucanía                               32
# X de los Lagos                                   30
# VII del Maule                                    30
# IV de Coquimbo                                   15
# XIV de los Ríos                                  12
# XII de Magallanes y Antártica Chilena            10
# XI Aysén del General Carlos Ibáñez del Campo     10
# II de Antofagasta                                 9
# III de Atacama                                    9
# I de Tarapacá                                     7
# XV de Arica y Parinacota                          4
# Name: count, dtype: int64

# %%
df2['Región'].value_counts() #Aquí me muestra las cantidades de personas por región que han sido consideradas para la evaluación
# Out:
# Región
# Metropolitana         52
# Valparaíso            38
# Biobío                33
#  O'Higgins            33
# La Araucanía          32
# Los Lagos             30
# Maule                 30
# Ñuble                 21
# Coquimbo              15
# Los Ríos              12
# Magallanes            10
# Aysén                 10
# Antofagasta            9
# Atacama                9
# Tarapacá               7
# Arica y Parinacota     4
# Name: count, dtype: int64

# %%
# Convertir columnas potencialmente numéricas de df a tipo numérico
num_cols_df = [
    'Número de personas en situación de pobreza por ingresos',
    'Porcentaje de personas en situación de pobreza por ingresos',
    'Límite inferior',
    'Límite superior'
]

for col in num_cols_df:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Convertir columnas potencialmente numéricas de df2 a tipo numérico
num_cols_df2 = [
    'Número de personas según proyecciones de población (*)',
    'Número de personas en situación de pobreza multidimensional (**)',
    'Porcentaje de personas en situacion de pobreza multidimensional 2024',
    'Límite inferior',
    'Límite superior'
]

for col in num_cols_df2:
    df2[col] = pd.to_numeric(df2[col], errors='coerce')

# %%
# Agrupación de columnas por tipos de datos para df
tipos_df = df.columns.to_series().groupby(df.dtypes).groups
ctext_df = tipos_df[np.dtype('object')]

columnas_df = df.columns
cnum_df = list(set(columnas_df) - set(ctext_df))

print(f"Columnas categóricas en df: {len(ctext_df)}")
print(f"Columnas numéricas en df: {len(cnum_df)}")
# Out:
# Columnas categóricas en df: 4
# Columnas numéricas en df: 4

# %%
# Agrupación de columnas por tipos de datos para df2
tipos_df2 = df2.columns.to_series().groupby(df2.dtypes).groups
ctext_df2 = tipos_df2[np.dtype('object')]

columnas_df2 = df2.columns
cnum_df2 = list(set(columnas_df2) - set(ctext_df2))

print(f"Columnas categóricas en df2: {len(ctext_df2)}")
print(f"Columnas numéricas en df2: {len(cnum_df2)}")
# Out:
# Columnas categóricas en df2: 5
# Columnas numéricas en df2: 5

# %%
# Completando valores faltantes datos cuantitativos para df
for columna in cnum_df:
  mean = df[columna].mean()
  df[columna] = df[columna].fillna(mean)

# %%
# Completando valores faltantes datos cuantitativos para df2
for columna in cnum_df2:
  mean = df2[columna].mean()
  df2[columna] = df2[columna].fillna(mean)

# %%
# Completando valores faltantes datos categóricos para df
for columna in ctext_df:
  mode = df[columna].mode()[0]
  df[columna] = df[columna].fillna(mode)
# Out:
# /tmp/ipykernel_15209/2989265960.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[columna] = df[columna].fillna(mode)

# %%
# Completando valores faltantes datos categóricos para df2
for columna in ctext_df2:
  mode = df2[columna].mode()[0]
  df2[columna] = df2[columna].fillna(mode)
# Out:
# /tmp/ipykernel_15209/1609132357.py:3: UserWarning: Unable to sort modes: '<' not supported between instances of 'str' and 'int'
#   mode = df2[columna].mode()[0]

# %%
print("Nulos en df después de la limpieza:")
print(df.isna().sum())
# Out:
# Nulos en df después de la limpieza:
# Código comuna                                                  0
# Región                                                         0
# Nombre comuna                                                  0
# Número de personas en situación de pobreza por ingresos        0
# Porcentaje de personas en situación de pobreza por ingresos    0
# Límite inferior                                                0
# Límite superior                                                0
# Metodología de Estimación                                      0
# dtype: int64

# %%
print("Nulos en df2 después de la limpieza:")
print(df2.isna().sum())
# Out:
# Nulos en df2 después de la limpieza:
# Código comuna                                                           0
# Región                                                                  0
# Nombre comuna                                                           0
# Número de personas según proyecciones de población (*)                  0
# Número de personas en situación de pobreza multidimensional (**)        0
# Porcentaje de personas en situacion de pobreza multidimensional 2024    0
# Límite inferior                                                         0
# Límite superior                                                         0
# Presencia de la comuna en la muestra Casen                              0
# Tipo de estimación SAE (***)                                            0
# dtype: int64

# %%
# Agrupando por Metodología de Estimación y contando las ocurrencias
metodologia_counts = df['Metodología de Estimación'].value_counts()

# Creando las leyendas del grafico con porcentajes y nombres de metodología
labels = [f'{name}\n{percentage:.2f}%' for name, percentage in zip(metodologia_counts.index, (metodologia_counts / metodologia_counts.sum() * 100))]

plt.pie(metodologia_counts, labels=labels, startangle=90)
plt.title('Porción por metodología')
plt.show()

# %%
#Se grafica cuantas personas hay por región dentro del df2
region_count = df2['Región'].value_counts()
print(region_count)
# Creando el gráfico de barras
plt.figure(figsize=(12, 6))
plt.bar(region_count.index, region_count.values, color='skyblue')
plt.xlabel('Región')
plt.ylabel('Número de ocurrencias')
plt.title('Distribución por Región')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# Región
# Metropolitana         58
# Valparaíso            38
# Biobío                33
#  O'Higgins            33
# La Araucanía          32
# Los Lagos             30
# Maule                 30
# Ñuble                 21
# Coquimbo              15
# Los Ríos              12
# Magallanes            10
# Aysén                 10
# Antofagasta            9
# Atacama                9
# Tarapacá               7
# Arica y Parinacota     4
# Name: count, dtype: int64

# %%
# Se estandariza el formato de los datos de región para que sean compatibles con los datos de la data frame 2
mapeo_region = {
    'I de Tarapacá': 'Tarapacá',
    'II de Antofagasta': 'Antofagasta',
    'III de Atacama': 'Atacama',
    'IV de Coquimbo': 'Coquimbo',
    'V de Valparaíso': 'Valparaíso',
    'VI del Libertador General Bernardo O\'Higgins': 'O\'Higgins',
    'VII del Maule': 'Maule',
    'VIII del Biobío': 'Biobío',
    'IX de la Araucanía': 'La Araucanía',
    'X de los Lagos': 'Los Lagos',
    'XI Aysén del General Carlos Ibáñez del Campo': 'Aysén',
    'XII de Magallanes y Antártica Chilena': 'Magallanes',
    'XIII Metropolitana de Santiago': 'Metropolitana',
    'XIV de los Ríos': 'Los Ríos',
    'XV de Arica y Parinacota': 'Arica y Parinacota'
}

df['Región_Normalizada'] = df['Región'].map(mapeo_region)

# %%
# Calculate region counts for 2015 (normalized) and 2024
personas_por_region_2015 = df['Región_Normalizada'].value_counts().rename('2015')
personas_por_region_2024 = df2['Región'].value_counts().rename('2024')

# Combine the counts into a single DataFrame for plotting
personas_por_regiones = pd.concat([personas_por_region_2015, personas_por_region_2024], axis=1).fillna(0)
personas_por_regiones = personas_por_regiones.sort_values(by='2024', ascending=False)

# Create a grouped bar chart
plt.figure(figsize=(14, 8))
personas_por_regiones.plot(kind='bar', figsize=(14, 8), color=['skyblue', 'lightcoral'])
plt.title('Comparación de Cantidad de Registros por Región (2015 vs 2024)')
plt.xlabel('Región')
plt.ylabel('Número de Registros')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Año')
plt.tight_layout()
plt.show()
